# %%
print("hello python")
# Out:
# hello python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = {
    "hours": [1, 2, 3, 4, 5, 6, 7, 8, 9],
    "score": [35, 40, 45, 50, 55, 60, 65, 72, 80]
}

df = pd.DataFrame(data)

df
# Out:
#    hours  score
# 0      1     35
# 1      2     40
# 2      3     45
# 3      4     50
# 4      5     55
# 5      6     60
# 6      7     65
# 7      8     72
# 8      9     80

# %%
df.describe()
# Out:
#           hours      score
# count  9.000000   9.000000
# mean   5.000000  55.777778
# std    2.738613  14.931324
# min    1.000000  35.000000
# 25%    3.000000  45.000000
# 50%    5.000000  55.000000
# 75%    7.000000  65.000000
# max    9.000000  80.000000

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df["hours"], df["score"])

plt.xlabel("Hours Studied")
plt.ylabel("Score")
plt.title("Study Hours vs Score")

plt.show()

# %%
X = df[["hours"]]
y = df["score"]

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[8]])

print("Predicted Score:", prediction[0])
# Out:
# Predicted Score: 72.07777777777778
# C:\Users\mokchhedul islam\Desktop\100daysdevops\100daysreview\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
